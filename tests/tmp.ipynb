# %%
import numpy as np

# %%
test_dump = "out_test/weights_adpq_quantized.npz"

loaded = np.load(test_dump, allow_pickle=True)
# Out:
# ['quantized_vectors', 'scale', 'zeropoint', 'outlier_indices', 'group_num', 'ADPQ_config']

# %%
# Out:
# {'group_size': 128, 'n_iters': 100, 'alpha': 0.06, 'device': 'cpu', 'q_bit': 4, 'data_packing': True, 'symmetrical_quantization': True}
